# %% [markdown]
# <a href="https://colab.research.google.com/github/jlchang/2024-04-12-Unix_Shell/blob/gh-pages/episodes/files/Python_Ep2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Intro to Python Epsiode 2
